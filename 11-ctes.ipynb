# %% [markdown]
# # Phase 10 — CTEs (Common Table Expressions)
#
# A CTE is a named temporary result defined at the top of a query with `WITH`. It makes complex queries readable by breaking them into named steps.
#
# ```sql
# WITH cte_name AS (
#     SELECT ...
# )
# SELECT * FROM cte_name;
# ```
#
# **CTE vs Subquery:** same result, but CTEs are reusable within the same query and easier to read.
#
# **Multiple CTEs:** chain with commas — each can reference the ones before it.
# ```sql
# WITH
#   cte1 AS (SELECT ...),
#   cte2 AS (SELECT ... FROM cte1)
# SELECT * FROM cte2;
# ```

# %%
# %pip install jupysql pymysql --quiet

# %%
# %load_ext sql
# %sql mysql+pymysql://root:root@127.0.0.1:3306/sakila

# %% [markdown]
# ---
# ## Basic CTE
#
# Customers with more than 30 rentals.

# %%
# %%sql
# -- Q1: Use a CTE to find customers who have made more than 30 rentals — join rental and customer — show first_name, last_name, and rental_count — order by rental_count DESC

# %% [markdown]
# ---
# ## Multiple CTEs
#
# Step 1: revenue per customer. Step 2: top 5 from that.

# %%
# %%sql
# -- Q2: Use two CTEs — first compute total revenue per customer from payment, then select the top 5 spenders — join with customer for names — show first_name, last_name, and total_spent

# %% [markdown]
# ---
# ## Practice Challenges
#
# 1. Use a CTE to find the average rental duration per film rating, show only ratings where average > 5 days
# 2. Use two CTEs: total payments per staff + total rentals per staff — join to show both side by side
# 3. Use a CTE to find films that have never been rented

# %%
# %%sql
# -- Q3: Use a CTE to compute the average rental_duration per film rating — from film table — show only ratings where the average is greater than 5 days — show rating and avg_duration

# %%
# %%sql
# -- Q4: Use two CTEs — one for total payment amount per staff member, one for total rental count per staff member — join them to show staff_id, total_payments, and total_rentals side by side

# %%
# %%sql
# -- Q5: Use a CTE to find films that have never been rented — from film, left join inventory, left join rental — show film_id and title
