# %% [markdown]
# # Phase 16 — DDL (Data Definition Language)
#
# DDL is the set of SQL commands that define and modify **structure** (not data).
#
# | Command | What it does |
# |---|---|
# | `CREATE TABLE` | Define a new table |
# | `ALTER TABLE` | Modify an existing table |
# | `DROP TABLE` | Delete a table and all its data |
# | `TRUNCATE TABLE` | Delete all rows, keep structure (faster than DELETE) |
#
# ## Common Data Types
#
# | Type | Use for |
# |---|---|
# | `INT` / `BIGINT` | Integers |
# | `DECIMAL(p, s)` | Exact decimals — money, measurements |
# | `FLOAT` / `DOUBLE` | Approximate decimals — avoid for money |
# | `VARCHAR(n)` | Variable-length string up to n chars |
# | `CHAR(n)` | Fixed-length string — wastes space but faster for short fixed values |
# | `TEXT` | Long text, no length limit |
# | `DATE` | Date only (YYYY-MM-DD) |
# | `DATETIME` | Date + time |
# | `TIMESTAMP` | Like DATETIME but stores UTC; auto-updates available |
# | `BOOLEAN` | TRUE/FALSE (stored as TINYINT 1/0) |
# | `ENUM(...)` | One value from a fixed list |
#
# ## Constraints
#
# | Constraint | Enforces |
# |---|---|
# | `PRIMARY KEY` | Unique + NOT NULL identifier |
# | `NOT NULL` | Column must always have a value |
# | `UNIQUE` | No duplicates allowed |
# | `DEFAULT value` | Value used when none is provided |
# | `FOREIGN KEY` | Value must exist in referenced table |
# | `CHECK` | Custom condition must be true |

# %%
# %pip install jupysql pymysql --quiet

# %%
# %load_ext sql
# %sql mysql+pymysql://root:root@127.0.0.1:3306/sakila

# %% [markdown]
# ---
# ## CREATE TABLE with constraints

# %%
# %%sql
# -- Q1: Create a review table — columns: review_id (PK, AUTO_INCREMENT), film_id (FK → film), customer_id (FK → customer), rating TINYINT with CHECK (1–5), body TEXT, created_at TIMESTAMP DEFAULT NOW()

# %% [markdown]
# ---
# ## Inspect the table structure

# %%
# %%sql
# -- Q2: Use DESCRIBE to inspect the structure of the review table you just created

# %% [markdown]
# ---
# ## ALTER TABLE — add, modify, drop columns

# %%
# %%sql
# -- Q3: Add a helpful_votes INT column with DEFAULT 0 to the review table using ALTER TABLE ADD COLUMN

# %%
# %%sql
# -- Q4: Rename the body column to review_text in the review table using ALTER TABLE RENAME COLUMN

# %%
# %%sql
# -- Q5: Change the helpful_votes column type from INT to SMALLINT in the review table using ALTER TABLE MODIFY COLUMN

# %%
# %%sql
# -- Q6: Remove the helpful_votes column from the review table using ALTER TABLE DROP COLUMN

# %% [markdown]
# ---
# ## DROP TABLE vs TRUNCATE TABLE
#
# - `DROP TABLE` removes the table entirely (structure + data)
# - `TRUNCATE TABLE` removes all rows but keeps the table structure; resets AUTO_INCREMENT

# %%
# %%sql
# -- Q7: Drop the review table entirely using DROP TABLE

# %% [markdown]
# ---
# ## Practice Challenges
#
# 1. Create a `wishlist` table: customers can save films they want to rent. Include appropriate FKs and a timestamp
# 2. Add a `priority` column (1–5) to `wishlist` with a CHECK constraint
# 3. Use `DESCRIBE` to inspect the `rental` table — identify which columns are NOT NULL vs nullable

# %%
# %%sql
# -- Q8: Create a wishlist table — columns: wishlist_id (PK, AUTO_INCREMENT), customer_id (FK → customer), film_id (FK → film), added_at TIMESTAMP DEFAULT NOW()

# %%
# %%sql
# -- Q9: Add a priority TINYINT column to the wishlist table with a CHECK constraint ensuring values are between 1 and 5 using ALTER TABLE

# %%
# %%sql
# -- Q10: Use DESCRIBE on the rental table to see all columns — identify which columns are NOT NULL vs nullable
