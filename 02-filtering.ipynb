# %% [markdown]
# # 02 — Filtering (WHERE)
# **Covers:** `WHERE`, comparison operators, `AND`/`OR`/`NOT`, `IN`, `BETWEEN`, `LIKE`, `IS NULL`
#
# **Tables used:** `film`, `actor`, `customer`, `payment`, `rental`

# %%
# %pip install jupysql pymysql --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext sql
# %sql mysql+pymysql://root:root@127.0.0.1:3306/sakila
# Out:
# Connecting to 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'

# %% [markdown]
# ---
# ## Concept 1 — WHERE and Comparison Operators
#
# `WHERE` filters rows **before** SELECT runs. Only rows that satisfy the condition are returned.
#
# ```sql
# SELECT title FROM film WHERE rental_rate = 4.99;
# SELECT title FROM film WHERE length > 120;
# SELECT title FROM film WHERE rating != 'G';
# ```
#
# | Operator | Meaning |
# |---|---|
# | `=` | equal |
# | `!=` or `<>` | not equal |
# | `>` / `<` | greater / less than |
# | `>=` / `<=` | greater or equal / less or equal |

# %%
# %%sql
# -- Q1: Get all films with rental_rate = 4.99
#
# SELECT * FROM film WHERE rental_rate = 4.99;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 336 rows affected.
# +---------+----------------------+---------------------------------------------------------------------------------------------------------+--------------+-------------+----------------------+-----------------+-------------+--------+------------------+--------+-----------------------------------------------+---------------------+
# | film_id |        title         |                                               description                                               | release_year | language_id | original_language_id | rental_duration | rental_rate | length | replacement_cost | rating |                special_features               |     last_update     |
# ...

# %%
# %%sql
# -- Q2: Get all films longer than 120 minutes — show title and length
#
# SELECT title, length FROM film WHERE length > 120;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 457 rows affected.
# +--------------------+--------+
# |       title        | length |
# +--------------------+--------+
# |    AFRICAN EGG     |  130   |
# |    AGENT TRUMAN    |  169   |
# |  ALAMO VIDEOTAPE   |  126   |
# |   ALASKA PHANTOM   |  136   |
# |    ALI FOREVER     |  150   |
# |  ALLEY EVOLUTION   |  180   |
# |  AMERICAN CIRCUS   |  129   |
# |  ANALYZE HOOSIERS  |  181   |
# |  ANONYMOUS HUMAN   |  179   |
# | ANTITRUST TOMATOES |  168   |
# +--------------------+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q3: Get all films with replacement_cost less than 10.00 — show title and replacement_cost
#
# SELECT title, replacement_cost FROM film WHERE replacement_cost < 10.00;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 41 rows affected.
# +------------------------+------------------+
# |         title          | replacement_cost |
# +------------------------+------------------+
# |  ANACONDA CONFESSIONS  |       9.99       |
# |      CIDER DESIRE      |       9.99       |
# |     CONTROL ANTHEM     |       9.99       |
# |    DAISY MENAGERIE     |       9.99       |
# | DELIVERANCE MULHOLLAND |       9.99       |
# |     DUDE BLINDNESS     |       9.99       |
# |      EDGE KISSING      |       9.99       |
# |       ENCINO ELF       |       9.99       |
# |     FACTORY DRAGON     |       9.99       |
# |   FELLOWSHIP AUTUMN    |       9.99       |
# +------------------------+------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q4: Get all films with rating = 'PG' — show title and rating
#
# SELECT title, rating FROM film WHERE rating = 'PG';
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 194 rows affected.
# +----------------------+--------+
# |        title         | rating |
# +----------------------+--------+
# |   ACADEMY DINOSAUR   |   PG   |
# |     AGENT TRUMAN     |   PG   |
# |    ALASKA PHANTOM    |   PG   |
# |     ALI FOREVER      |   PG   |
# |     AMADEUS HOLY     |   PG   |
# |     ARIZONA BANG     |   PG   |
# | ARSENIC INDEPENDENCE |   PG   |
# |  BEDAZZLED MARRIED   |   PG   |
# |   BEHAVIOR RUNAWAY   |   PG   |
# |     BILL OTHERS      |   PG   |
# +----------------------+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q5: Get all films where rental_duration is not equal to 3
#
# SELECT * FROM film WHERE rental_duration != 3;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 797 rows affected.
# +---------+------------------+-----------------------------------------------------------------------------------------------------------------------+--------------+-------------+----------------------+-----------------+-------------+--------+------------------+--------+----------------------------------+---------------------+
# | film_id |      title       |                                                      description                                                      | release_year | language_id | original_language_id | rental_duration | rental_rate | length | replacement_cost | rating |         special_features         |     last_update     |
# ...

# %% [markdown]
# ---
# ## Concept 2 — AND, OR, NOT
#
# Combine multiple conditions:
#
# ```sql
# -- AND: both conditions must be true
# SELECT title FROM film WHERE rating = 'PG' AND length > 100;
#
# -- OR: at least one condition must be true
# SELECT title FROM film WHERE rating = 'G' OR rating = 'PG';
#
# -- NOT: inverts the condition
# SELECT title FROM film WHERE NOT rating = 'R';
# ```
#
# ⚠️ Use parentheses when mixing AND and OR — AND has higher precedence than OR:
# ```sql
# -- Without parens: AND binds first, giving wrong logic
# WHERE rating = 'G' OR rating = 'PG' AND length > 100
#
# -- Correct: use parens to control grouping
# WHERE (rating = 'G' OR rating = 'PG') AND length > 100
# ```

# %%
# %%sql
# -- Q6: Get films rated 'PG' AND longer than 100 minutes — show title, rating, length
#
# SELECT title, rating, length FROM film WHERE rating = 'PG' AND length > 100;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 113 rows affected.
# +----------------------+--------+--------+
# |        title         | rating | length |
# +----------------------+--------+--------+
# |     AGENT TRUMAN     |   PG   |  169   |
# |    ALASKA PHANTOM    |   PG   |  136   |
# |     ALI FOREVER      |   PG   |  150   |
# |     AMADEUS HOLY     |   PG   |  113   |
# |     ARIZONA BANG     |   PG   |  121   |
# | ARSENIC INDEPENDENCE |   PG   |  137   |
# |   BIRCH ANTITRUST    |   PG   |  162   |
# |     BOILED DARES     |   PG   |  102   |
# |     BORN SPINAL      |   PG   |  179   |
# |  BRANNIGAN SUNRISE   |   PG   |  121   |
# +----------------------+--------+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q7: Get films rated 'G' OR 'PG' — show title and rating
#
# SELECT title, rating FROM film WHERE rating = 'PG' OR rating = 'G';
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 372 rows affected.
# +-------------------+--------+
# |       title       | rating |
# +-------------------+--------+
# |  ACADEMY DINOSAUR |   PG   |
# |   ACE GOLDFINGER  |   G    |
# |  AFFAIR PREJUDICE |   G    |
# |    AFRICAN EGG    |   G    |
# |    AGENT TRUMAN   |   PG   |
# |  ALAMO VIDEOTAPE  |   G    |
# |   ALASKA PHANTOM  |   PG   |
# |    ALI FOREVER    |   PG   |
# |    AMADEUS HOLY   |   PG   |
# | AMISTAD MIDSUMMER |   G    |
# +-------------------+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q8: Get films where rental_rate > 2.99 AND rental_duration < 5
#
# SELECT * FROM film WHERE rental_rate > 2.99 AND rental_duration < 5;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 132 rows affected.
# +---------+---------------------+-------------------------------------------------------------------------------------------------------+--------------+-------------+----------------------+-----------------+-------------+--------+------------------+--------+--------------------------------------------------------+---------------------+
# | film_id |        title        |                                              description                                              | release_year | language_id | original_language_id | rental_duration | rental_rate | length | replacement_cost | rating |                    special_features                    |     last_update     |
# ...

# %%
# %%sql
# -- Q9: Get films rated 'R' OR longer than 150 minutes — show title, rating, length
#
# SELECT title, rating, length FROM film WHERE rating = 'R' OR length > 150;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 385 rows affected.
# +----------------------+--------+--------+
# |        title         | rating | length |
# +----------------------+--------+--------+
# |     AGENT TRUMAN     |   PG   |  169   |
# |   AIRPORT POLLOCK    |   R    |   54   |
# |   ALLEY EVOLUTION    | NC-17  |  180   |
# |      ALONE TRIP      |   R    |   82   |
# | AMELIE HELLFIGHTERS  |   R    |   79   |
# |   AMERICAN CIRCUS    |   R    |  129   |
# | ANACONDA CONFESSIONS |   R    |   92   |
# |   ANALYZE HOOSIERS   |   R    |  181   |
# |   ANONYMOUS HUMAN    | NC-17  |  179   |
# |  ANTITRUST TOMATOES  | NC-17  |  168   |
# +----------------------+--------+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q10: Get films that are NOT rated 'R' AND have a rental_rate of 4.99
#
# SELECT * FROM film WHERE NOT rating = 'R' AND rental_rate = 4.99;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 271 rows affected.
# +---------+-------------------+---------------------------------------------------------------------------------------------------------------------+--------------+-------------+----------------------+-----------------+-------------+--------+------------------+--------+--------------------------------------------------------+---------------------+
# | film_id |       title       |                                                     description                                                     | release_year | language_id | original_language_id | rental_duration | rental_rate | length | replacement_cost | rating |                    special_features                    |     last_update     |
# ...

# %%
# %%sql
# -- Q11: Get films where (rating = 'G' OR rating = 'PG') AND length > 100
# --      Show title, rating, length — note the parentheses!
#
# SELECT title, rating, length FROM film WHERE (rating = 'G' OR rating = 'PG') AND length > 100;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 213 rows affected.
# +----------------------+--------+--------+
# |        title         | rating | length |
# +----------------------+--------+--------+
# |   AFFAIR PREJUDICE   |   G    |  117   |
# |     AFRICAN EGG      |   G    |  130   |
# |     AGENT TRUMAN     |   PG   |  169   |
# |   ALAMO VIDEOTAPE    |   G    |  126   |
# |    ALASKA PHANTOM    |   PG   |  136   |
# |     ALI FOREVER      |   PG   |  150   |
# |     AMADEUS HOLY     |   PG   |  113   |
# |     ARIZONA BANG     |   PG   |  121   |
# | ARSENIC INDEPENDENCE |   PG   |  137   |
# |    ATLANTIS CAUSE    |   G    |  170   |
# +----------------------+--------+--------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ---
# ## Concept 3 — IN and NOT IN
#
# `IN` checks if a value matches any value in a list — cleaner than multiple OR conditions:
#
# ```sql
# -- These two are equivalent:
# WHERE rating = 'G' OR rating = 'PG' OR rating = 'PG-13'
# WHERE rating IN ('G', 'PG', 'PG-13')
# ```
#
# `NOT IN` excludes those values:
# ```sql
# SELECT title FROM film WHERE rating NOT IN ('R', 'NC-17');
# ```

# %%
# %%sql
# -- Q12: Get films with rating IN ('G', 'PG', 'PG-13') — show title and rating
#
# SELECT title, rating FROM film WHERE rating IN ('G', 'PG', 'PG-13');
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 595 rows affected.
# +------------------+--------+
# |      title       | rating |
# +------------------+--------+
# | ACADEMY DINOSAUR |   PG   |
# |  ACE GOLDFINGER  |   G    |
# | AFFAIR PREJUDICE |   G    |
# |   AFRICAN EGG    |   G    |
# |   AGENT TRUMAN   |   PG   |
# | AIRPLANE SIERRA  | PG-13  |
# |  ALABAMA DEVIL   | PG-13  |
# | ALAMO VIDEOTAPE  |   G    |
# |  ALASKA PHANTOM  |   PG   |
# |   ALI FOREVER    |   PG   |
# +------------------+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q13: Get films where rental_duration IN (3, 5, 7) — show title and rental_duration
#
# SELECT title, rental_duration FROM film WHERE rental_duration IN (3,5,7);
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 585 rows affected.
# +----------------------+-----------------+
# |        title         | rental_duration |
# +----------------------+-----------------+
# |    ACE GOLDFINGER    |        3        |
# |   ADAPTATION HOLES   |        7        |
# |   AFFAIR PREJUDICE   |        5        |
# |     AGENT TRUMAN     |        3        |
# |    ALABAMA DEVIL     |        3        |
# |     ALIEN CENTER     |        5        |
# |      ALONE TRIP      |        3        |
# |   AMERICAN CIRCUS    |        3        |
# | ANACONDA CONFESSIONS |        3        |
# |     ANGELS LIFE      |        3        |
# +----------------------+-----------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q14: Get films NOT IN ratings 'R' or 'NC-17' — show title and rating
#
# SELECT title, rating FROM film WHERE rating NOT IN ('R', 'NC-17');
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 595 rows affected.
# +------------------+--------+
# |      title       | rating |
# +------------------+--------+
# | ACADEMY DINOSAUR |   PG   |
# |  ACE GOLDFINGER  |   G    |
# | AFFAIR PREJUDICE |   G    |
# |   AFRICAN EGG    |   G    |
# |   AGENT TRUMAN   |   PG   |
# | AIRPLANE SIERRA  | PG-13  |
# |  ALABAMA DEVIL   | PG-13  |
# | ALAMO VIDEOTAPE  |   G    |
# |  ALASKA PHANTOM  |   PG   |
# |   ALI FOREVER    |   PG   |
# +------------------+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q15: Get films where rental_rate NOT IN (0.99, 2.99) — show title and rental_rate
#
# SELECT title, rental_rate FROM film WHERE rental_rate NOT IN (0.99, 2.99);
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 336 rows affected.
# +----------------------+-------------+
# |        title         | rental_rate |
# +----------------------+-------------+
# |    ACE GOLDFINGER    |     4.99    |
# |   AIRPLANE SIERRA    |     4.99    |
# |   AIRPORT POLLOCK    |     4.99    |
# |   ALADDIN CALENDAR   |     4.99    |
# |     ALI FOREVER      |     4.99    |
# | AMELIE HELLFIGHTERS  |     4.99    |
# |   AMERICAN CIRCUS    |     4.99    |
# |     ANTHEM LUKE      |     4.99    |
# |    APACHE DIVINE     |     4.99    |
# | APOCALYPSE FLAMINGOS |     4.99    |
# +----------------------+-------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ---
# ## Concept 4 — BETWEEN
#
# `BETWEEN` filters for values within an inclusive range:
#
# ```sql
# SELECT title FROM film WHERE length BETWEEN 90 AND 120;
# -- equivalent to: WHERE length >= 90 AND length <= 120
# ```
#
# Works on numbers, dates, and strings:
# ```sql
# WHERE payment_date BETWEEN '2005-06-01' AND '2005-06-30'
# ```

# %%
# %%sql
# -- Q16: Get films with length BETWEEN 90 AND 120 minutes — show title and length
#
# SELECT title, length FROM film WHERE length BETWEEN 90 AND 120;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 223 rows affected.
# +----------------------+--------+
# |        title         | length |
# +----------------------+--------+
# |   AFFAIR PREJUDICE   |  117   |
# |    ALABAMA DEVIL     |  114   |
# |    ALICE FANTASIA    |   94   |
# |     AMADEUS HOLY     |  113   |
# | ANACONDA CONFESSIONS |   92   |
# |     ANTHEM LUKE      |   91   |
# |    APACHE DIVINE     |   92   |
# | APOCALYPSE FLAMINGOS |  119   |
# |   ARMAGEDDON LOST    |   99   |
# |     ATTACKS HATE     |  113   |
# +----------------------+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q17: Get films with rental_rate BETWEEN 2.00 AND 4.00 — show title and rental_rate
#
# SELECT title, rental_rate FROM film WHERE rental_rate BETWEEN 2 AND 4;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 323 rows affected.
# +-------------------+-------------+
# |       title       | rental_rate |
# +-------------------+-------------+
# |  ADAPTATION HOLES |     2.99    |
# |  AFFAIR PREJUDICE |     2.99    |
# |    AFRICAN EGG    |     2.99    |
# |    AGENT TRUMAN   |     2.99    |
# |   ALABAMA DEVIL   |     2.99    |
# |    ALIEN CENTER   |     2.99    |
# |  ALLEY EVOLUTION  |     2.99    |
# | AMISTAD MIDSUMMER |     2.99    |
# |  ANALYZE HOOSIERS |     2.99    |
# |    ANGELS LIFE    |     2.99    |
# +-------------------+-------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q18: Get payments with amount BETWEEN 5.00 AND 10.00 — show payment_id, amount, payment_date
#
# SELECT payment_id, amount, payment_date FROM payment WHERE amount BETWEEN 5 AND 10;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 3843 rows affected.
# +------------+--------+---------------------+
# | payment_id | amount |     payment_date    |
# +------------+--------+---------------------+
# |     3      |  5.99  | 2005-06-15 00:54:12 |
# |     5      |  9.99  | 2005-06-15 21:08:46 |
# |     10     |  5.99  | 2005-07-08 03:17:05 |
# |     11     |  5.99  | 2005-07-08 07:33:56 |
# |     14     |  7.99  | 2005-07-11 10:13:46 |
# |     32     |  5.99  | 2005-08-22 20:03:46 |
# |     36     |  6.99  | 2005-07-10 12:38:56 |
# |     38     |  5.99  | 2005-07-27 15:23:02 |
# |     39     |  5.99  | 2005-07-27 18:40:20 |
# |     40     |  5.99  | 2005-07-29 00:12:59 |
# +------------+--------+---------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q19: Get payments made in June 2005 using BETWEEN on payment_date
#
# SELECT payment_id, amount, payment_date FROM payment WHERE payment_date BETWEEN '2005-06-01' AND '2005-06-30';
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 2311 rows affected.
# +------------+--------+---------------------+
# | payment_id | amount |     payment_date    |
# +------------+--------+---------------------+
# |     3      |  5.99  | 2005-06-15 00:54:12 |
# |     4      |  0.99  | 2005-06-15 18:02:53 |
# |     5      |  9.99  | 2005-06-15 21:08:46 |
# |     6      |  4.99  | 2005-06-16 15:18:57 |
# |     7      |  4.99  | 2005-06-18 08:41:48 |
# |     8      |  0.99  | 2005-06-18 13:33:59 |
# |     9      |  3.99  | 2005-06-21 06:24:45 |
# |     34     |  2.99  | 2005-06-17 20:54:58 |
# |     62     |  8.99  | 2005-06-16 01:34:05 |
# |     63     |  6.99  | 2005-06-16 15:19:10 |
# +------------+--------+---------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ---
# ## Concept 5 — LIKE (Pattern Matching)
#
# `LIKE` matches string patterns using wildcards:
#
# | Wildcard | Meaning |
# |---|---|
# | `%` | zero or more of any character |
# | `_` | exactly one of any character |
#
# ```sql
# WHERE title LIKE 'A%'        -- starts with A
# WHERE title LIKE '%love%'    -- contains "love" anywhere
# WHERE title LIKE '%ing'      -- ends with "ing"
# WHERE title LIKE '_AT%'      -- second and third chars are A and T
# ```
#
# `NOT LIKE` excludes matching rows:
# ```sql
# WHERE title NOT LIKE 'A%'
# ```

# %%
# %%sql
# -- Q20: Get films whose title starts with 'A' — show title
#
# SELECT title FROM film WHERE title LIKE 'A%';
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 46 rows affected.
# +------------------+
# |      title       |
# +------------------+
# | ACADEMY DINOSAUR |
# |  ACE GOLDFINGER  |
# | ADAPTATION HOLES |
# | AFFAIR PREJUDICE |
# |   AFRICAN EGG    |
# |   AGENT TRUMAN   |
# | AIRPLANE SIERRA  |
# | AIRPORT POLLOCK  |
# |  ALABAMA DEVIL   |
# | ALADDIN CALENDAR |
# +------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q21: Get films whose title ends with 'ing' — show title
#
# SELECT title FROM film WHERE title LIKE '%ing';
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 32 rows affected.
# +-------------------------+
# |          title          |
# +-------------------------+
# |     CASSIDY WYOMING     |
# |   COLDBLOODED DARLING   |
# |     COMMAND DARLING     |
# |     CRYSTAL BREAKING    |
# |     DARLING BREAKING    |
# | DESPERATE TRAINSPOTTING |
# |     DIVORCE SHINING     |
# |       DOOM DANCING      |
# |      DORADO NOTTING     |
# |       EDGE KISSING      |
# +-------------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q22: Get films whose title contains the word 'love' anywhere — show title
#
# SELECT title FROM film WHERE title LIKE '%love%';
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 10 rows affected.
# +--------------------+
# |       title        |
# +--------------------+
# |   GRAFFITI LOVE    |
# |     IDAHO LOVE     |
# |   IDENTITY LOVER   |
# |    INDIAN LOVE     |
# |   LAWRENCE LOVE    |
# |   LOVE SUICIDES    |
# |   LOVELY JINGLE    |
# |    LOVER TRUMAN    |
# |  LOVERBOY ATTACKS  |
# | STRANGELOVE DESIRE |
# +--------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q23: Get actors whose last_name starts with 'W' — show first_name and last_name
#
# SELECT first_name, last_name FROM actor WHERE last_name LIKE 'W%';
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 19 rows affected.
# +-------------+-----------+
# |  first_name | last_name |
# +-------------+-----------+
# |     NICK    |  WAHLBERG |
# |    DARYL    |  WAHLBERG |
# |     BELA    |   WALKEN  |
# |     ALEC    |   WAYNE   |
# | CHRISTOPHER |    WEST   |
# |    REESE    |    WEST   |
# |     SEAN    |  WILLIAMS |
# |    MORGAN   |  WILLIAMS |
# |   GROUCHO   |  WILLIAMS |
# |     BEN     |   WILLIS  |
# +-------------+-----------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q24: Get customers whose email ends with '@sakilacustomer.org' — show first_name, last_name, email
#
# SELECT first_name, last_name, email FROM customer WHERE email LIKE '%@sakilacustomer.org';
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 599 rows affected.
# +------------+-----------+-------------------------------------+
# | first_name | last_name |                email                |
# +------------+-----------+-------------------------------------+
# |    MARY    |   SMITH   |    MARY.SMITH@sakilacustomer.org    |
# |  PATRICIA  |  JOHNSON  | PATRICIA.JOHNSON@sakilacustomer.org |
# |   LINDA    |  WILLIAMS |  LINDA.WILLIAMS@sakilacustomer.org  |
# |  BARBARA   |   JONES   |   BARBARA.JONES@sakilacustomer.org  |
# | ELIZABETH  |   BROWN   |  ELIZABETH.BROWN@sakilacustomer.org |
# |  JENNIFER  |   DAVIS   |  JENNIFER.DAVIS@sakilacustomer.org  |
# |   MARIA    |   MILLER  |   MARIA.MILLER@sakilacustomer.org   |
# |   SUSAN    |   WILSON  |   SUSAN.WILSON@sakilacustomer.org   |
# |  MARGARET  |   MOORE   |  MARGARET.MOORE@sakilacustomer.org  |
# |  DOROTHY   |   TAYLOR  |  DOROTHY.TAYLOR@sakilacustomer.org  |
# ...

# %%
# %%sql
# -- Q25: Get films whose title does NOT start with 'A' — show title (limit 10)
#
# SELECT title FROM film WHERE title NOT LIKE 'A%';
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 954 rows affected.
# +----------------------+
# |        title         |
# +----------------------+
# |      BABY HALL       |
# | BACKLASH UNDEFEATED  |
# |     BADMAN DAWN      |
# |   BAKED CLEOPATRA    |
# |   BALLOON HOMEWARD   |
# | BALLROOM MOCKINGBIRD |
# |      BANG KWAI       |
# |   BANGER PINOCCHIO   |
# | BARBARELLA STREETCAR |
# | BAREFOOT MANCHURIAN  |
# +----------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ---
# ## Concept 6 — IS NULL and IS NOT NULL
#
# `NULL` means missing or unknown. You **cannot** compare NULL with `=` — it will never match:
#
# ```sql
# -- WRONG — never returns rows:
# WHERE original_language_id = NULL
#
# -- CORRECT:
# WHERE original_language_id IS NULL
# WHERE original_language_id IS NOT NULL
# ```
#
# NULL is not zero, not empty string — it means the value is absent.

# %%
# %%sql
# -- Q26: Get films where original_language_id IS NULL — show title
#
# SELECT title FROM film WHERE original_language_id IS NULL;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 1000 rows affected.
# +------------------+
# |      title       |
# +------------------+
# | ACADEMY DINOSAUR |
# |  ACE GOLDFINGER  |
# | ADAPTATION HOLES |
# | AFFAIR PREJUDICE |
# |   AFRICAN EGG    |
# |   AGENT TRUMAN   |
# | AIRPLANE SIERRA  |
# | AIRPORT POLLOCK  |
# |  ALABAMA DEVIL   |
# | ALADDIN CALENDAR |
# +------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q27: Get films where original_language_id IS NOT NULL — show title
#
# SELECT title FROM film WHERE original_language_id IS NOT NULL;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# +-------+
# | title |
# +-------+
# +-------+

# %%
# %%sql
# -- Q28: Get rentals where return_date IS NULL (films not yet returned) — show rental_id, rental_date
#
# SELECT rental_id, rental_date FROM rental WHERE return_date IS NULL;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 183 rows affected.
# +-----------+---------------------+
# | rental_id |     rental_date     |
# +-----------+---------------------+
# |   11496   | 2006-02-14 15:16:03 |
# |   11541   | 2006-02-14 15:16:03 |
# |   11563   | 2006-02-14 15:16:03 |
# |   11577   | 2006-02-14 15:16:03 |
# |   11593   | 2006-02-14 15:16:03 |
# |   11611   | 2006-02-14 15:16:03 |
# |   11646   | 2006-02-14 15:16:03 |
# |   11652   | 2006-02-14 15:16:03 |
# |   11657   | 2006-02-14 15:16:03 |
# |   11672   | 2006-02-14 15:16:03 |
# +-----------+---------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q29: Get rentals where return_date IS NOT NULL (films already returned) — show rental_id, return_date
#
# SELECT rental_id, rental_date FROM rental WHERE return_date IS NOT NULL;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 15861 rows affected.
# +-----------+---------------------+
# | rental_id |     rental_date     |
# +-----------+---------------------+
# |     1     | 2005-05-24 22:53:30 |
# |     2     | 2005-05-24 22:54:33 |
# |     3     | 2005-05-24 23:03:39 |
# |     4     | 2005-05-24 23:04:41 |
# |     5     | 2005-05-24 23:05:21 |
# |     6     | 2005-05-24 23:08:07 |
# |     7     | 2005-05-24 23:11:53 |
# |     8     | 2005-05-24 23:31:46 |
# |     9     | 2005-05-25 00:00:40 |
# |     10    | 2005-05-25 00:02:21 |
# +-----------+---------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ---
# ## Mixed Challenges
#
# No hints — combine any filtering concepts from this notebook.

# %%
# %%sql
# -- Q30: Get films rated 'PG' or 'PG-13' with length > 100 and rental_rate < 4.99
# --      Show title, rating, length, rental_rate. Sort by length DESC.
#
# SELECT
#     title, rating, length, rental_rate
# FROM film
# WHERE rating IN ('PG', 'PG-13') AND length > 100 AND rental_rate < 4.99
# ORDER BY length DESC;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 167 rows affected.
# +-------------------+--------+--------+-------------+
# |       title       | rating | length | rental_rate |
# +-------------------+--------+--------+-------------+
# |    GANGS PRIDE    | PG-13  |  185   |     2.99    |
# |    POND SEATTLE   | PG-13  |  185   |     2.99    |
# |    WORST BANGER   |   PG   |  185   |     2.99    |
# | CONSPIRACY SPIRIT | PG-13  |  184   |     2.99    |
# |   THEORY MERMAID  | PG-13  |  184   |     0.99    |
# |   JACKET FRISCO   | PG-13  |  181   |     2.99    |
# |   STAR OPERATION  |   PG   |  181   |     2.99    |
# |   IMPACT ALADDIN  | PG-13  |  180   |     0.99    |
# |    MIXED DOORS    | PG-13  |  180   |     2.99    |
# |   NASH CHOCOLAT   | PG-13  |  180   |     2.99    |
# +-------------------+--------+--------+-------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q31: Get films whose title starts with 'S', rating IN ('G','PG'), and length BETWEEN 80 AND 130
# --      Show title, rating, length
#
# SELECT
#     title, rating, length
# FROM film
# WHERE title LIKE 'S%' AND rating IN ('G','PG') AND length BETWEEN 80 AND 130;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 18 rows affected.
# +--------------------+--------+--------+
# |       title        | rating | length |
# +--------------------+--------+--------+
# |  SABRINA MIDNIGHT  |   PG   |   99   |
# | SAGEBRUSH CLUELESS |   G    |  106   |
# |    SAINTS BRIDE    |   G    |  125   |
# |    SAMURAI LION    |   G    |  110   |
# |     SEA VIRGIN     |   PG   |   80   |
# |  SECRET GROUNDHOG  |   PG   |   90   |
# |  SECRETS PARADISE  |   G    |  109   |
# |  SENSIBILITY REAR  |   PG   |   98   |
# |   SHANE DARKNESS   |   PG   |   93   |
# |  SHAWSHANK BUBBLE  |   PG   |   80   |
# +--------------------+--------+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q32: Get active customers (active = 1) whose email ends with '@sakilacustomer.org'
# --      Show full name (CONCAT) as 'full_name' and email. Sort by last_name.
#
# SELECT
#     CONCAT(first_name, ' ', last_name) AS full_name,
#     email
# FROM customer
# WHERE active = 1 AND email LIKE '%@sakilacustomer.org'
# ORDER BY last_name;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 584 rows affected.
# +------------------+-------------------------------------+
# |    full_name     |                email                |
# +------------------+-------------------------------------+
# |   RAFAEL ABNEY   |   RAFAEL.ABNEY@sakilacustomer.org   |
# |  NATHANIEL ADAM  |  NATHANIEL.ADAM@sakilacustomer.org  |
# |  KATHLEEN ADAMS  |  KATHLEEN.ADAMS@sakilacustomer.org  |
# | DIANA ALEXANDER  |  DIANA.ALEXANDER@sakilacustomer.org |
# |  GORDON ALLARD   |   GORDON.ALLARD@sakilacustomer.org  |
# |  SHIRLEY ALLEN   |   SHIRLEY.ALLEN@sakilacustomer.org  |
# | CHARLENE ALVAREZ | CHARLENE.ALVAREZ@sakilacustomer.org |
# |  LISA ANDERSON   |   LISA.ANDERSON@sakilacustomer.org  |
# |   JOSE ANDREW    |    JOSE.ANDREW@sakilacustomer.org   |
# |   IDA ANDREWS    |    IDA.ANDREWS@sakilacustomer.org   |
# +------------------+-------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q33: Get payments with amount > 7.00 made in July 2005
# --      Show payment_id, amount, payment_date. Sort by amount DESC.
#
# SELECT
#     payment_id, amount, payment_date
# FROM payment
# WHERE amount > 7.00 AND payment_date LIKE '2005-07-%'
# ORDER BY amount DESC;
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 659 rows affected.
# +------------+--------+---------------------+
# | payment_id | amount |     payment_date    |
# +------------+--------+---------------------+
# |    342     | 11.99  | 2005-07-29 22:37:41 |
# |   15821    | 11.99  | 2005-07-07 20:45:51 |
# |   15850    | 11.99  | 2005-07-06 22:58:31 |
# |     44     | 10.99  | 2005-07-30 13:47:43 |
# |     69     | 10.99  | 2005-07-27 20:23:12 |
# |    793     | 10.99  | 2005-07-09 21:55:19 |
# |    1347    | 10.99  | 2005-07-29 11:15:36 |
# |    1379    | 10.99  | 2005-07-31 07:09:55 |
# |    2341    | 10.99  | 2005-07-28 10:21:52 |
# |    3078    | 10.99  | 2005-07-29 12:32:20 |
# +------------+--------+---------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Q34: Get films where replacement_cost > 20 AND rating NOT IN ('R', 'NC-17')
# --      AND title LIKE 'B%'. Show title, rating, replacement_cost.
#
# SELECT
#     title, rating, replacement_cost
# FROM film
# WHERE replacement_cost > 20 AND rating NOT IN ('R', 'NC-17') AND title LIKE 'B%';
# Out:
# Running query in 'mysql+pymysql://root:***@127.0.0.1:3306/sakila'
# 19 rows affected.
# +----------------------+--------+------------------+
# |        title         | rating | replacement_cost |
# +----------------------+--------+------------------+
# | BACKLASH UNDEFEATED  | PG-13  |      24.99       |
# |   BAKED CLEOPATRA    |   G    |      20.99       |
# | BALLROOM MOCKINGBIRD |   G    |      29.99       |
# | BARBARELLA STREETCAR |   G    |      27.99       |
# |    BEAUTY GREASE     |   G    |      28.99       |
# |  BEDAZZLED MARRIED   |   PG   |      21.99       |
# |  BEETHOVEN EXORCIST  | PG-13  |      26.99       |
# |   BEHAVIOR RUNAWAY   |   PG   |      20.99       |
# |     BERETS AGENT     | PG-13  |      24.99       |
# |   BILKO ANONYMOUS    | PG-13  |      25.99       |
# +----------------------+--------+------------------+
# Truncated to displaylimit of 10.
