# %% [markdown]
# # Phase 15 — Views
#
# A view is a saved SELECT query stored in the database with a name. You query it like a table.
#
# ```sql
# CREATE VIEW view_name AS
# SELECT ...;
#
# SELECT * FROM view_name;
#
# DROP VIEW view_name;
# ```
#
# **Why use views:**
# - Simplify complex joins — expose a clean interface to applications
# - Security — grant access to a view without exposing underlying tables
# - Reusability — write a complex query once, use it everywhere
#
# **Key limitation:** Views don't store data — they re-run the query every time you SELECT from them. For performance, use materialized views (not available in MySQL — use a summary table instead).
#
# **Updatable views:** A view is updatable (INSERT/UPDATE/DELETE) only if it maps 1:1 to a single table and has no GROUP BY, DISTINCT, aggregates, or JOINs.

# %%
# %pip install jupysql pymysql --quiet

# %%
# %load_ext sql
# %sql mysql+pymysql://root:root@127.0.0.1:3306/sakila

# %% [markdown]
# ---
# ## Sakila already has views — inspect them

# %%
# %%sql
# -- Q1: List all views in the sakila database — use SHOW FULL TABLES WHERE Table_type = 'VIEW'

# %% [markdown]
# ---
# ## Query an existing view
#
# `film_list` is a pre-built view that joins film, category, and actor.

# %%
# %%sql
# -- Q2: Select all columns from the film_list view — limit to 10 rows — observe what columns the view exposes

# %% [markdown]
# ---
# ## See the SQL behind a view

# %%
# %%sql
# -- Q3: Use SHOW CREATE VIEW film_list to inspect the SQL definition behind the view

# %% [markdown]
# ---
# ## Create your own view
#
# Active customers with their city.

# %%
# %%sql
# -- Q4: Create a view called active_customers — show customer_id, full name as full_name, email, and city — join customer, address, and city — only include rows where active = 1

# %%
# %%sql
# -- Q5: Select all columns from the active_customers view you just created — limit to 10 rows

# %% [markdown]
# ---
# ## Drop a view

# %%
# %%sql
# -- Q6: Drop the active_customers view using DROP VIEW

# %% [markdown]
# ---
# ## Practice Challenges
#
# 1. Create a view `film_revenue` that shows each film title and its total rental revenue
# 2. Create a view `overdue_rentals` that shows rentals where return_date is NULL (never returned)
# 3. Query the built-in `sales_by_store` view and describe what it shows

# %%
# %%sql
# -- Q7: Create a view called film_revenue — show each film's title and its total rental revenue — join film, inventory, rental, and payment — label the revenue column total_revenue

# %%
# %%sql
# -- Q8: Create a view called overdue_rentals — show all rentals where return_date IS NULL (never returned) — from rental table — show rental_id, rental_date, and customer_id

# %%
# %%sql
# -- Q9: Query the built-in sales_by_store view — select all columns — observe what store-level information it exposes
