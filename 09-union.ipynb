# %% [markdown]
# # Phase 14 — UNION / UNION ALL
#
# Combines result sets from two or more SELECT statements into one.
#
# ```sql
# SELECT col1, col2 FROM table_a
# UNION
# SELECT col1, col2 FROM table_b;
# ```
#
# **Rules:**
# - Both queries must return the **same number of columns**
# - Columns are matched by **position**, not name
# - The column names in the result come from the **first** SELECT
#
# | Operator | Duplicates |
# |---|---|
# | `UNION` | Removes duplicates (slower — does a distinct pass) |
# | `UNION ALL` | Keeps all rows including duplicates (faster) |
#
# **When to use UNION vs JOIN:**
# - JOIN → combine columns from related tables (horizontal)
# - UNION → stack rows from similar queries (vertical)

# %%
# %pip install jupysql pymysql --quiet

# %%
# %load_ext sql
# %sql mysql+pymysql://root:root@127.0.0.1:3306/sakila

# %% [markdown]
# ---
# ## UNION — combine staff and customer names into one list
#
# Useful for finding all people in the system regardless of role.

# %%
# %%sql
# -- Q1: Combine first_name, last_name from the customer table and the staff table into one list — add a role column showing 'Customer' or 'Staff' — use UNION

# %% [markdown]
# ---
# ## UNION ALL — keep duplicates (faster)
#
# If the same person were in both tables, UNION would deduplicate, UNION ALL would show them twice.

# %%
# %%sql
# -- Q2: Stack all rows from customer and all rows from staff using UNION ALL — show first_name, last_name, email, and a source column ('customer' or 'staff')

# %% [markdown]
# ---
# ## UNION with different conditions on the same table
#
# Get a combined list: films under $1 and films over $4 (the extremes).

# %%
# %%sql
# -- Q3: Use UNION ALL to get films with rental_rate = 0.99 and films with rental_rate = 4.99 from the film table — add a tier column 'Budget' or 'Premium' — show title, rental_rate, and tier

# %% [markdown]
# ---
# ## ORDER BY and LIMIT with UNION
#
# `ORDER BY` and `LIMIT` after a UNION apply to the **combined** result. To sort/limit individual parts, wrap them in subqueries.

# %%
# %%sql
# -- Q4: Use UNION ALL with subqueries to show the top 3 customers by last_name alphabetically and the top 3 staff by last_name — show last_name, first_name, and a source column ('customer' or 'staff')

# %% [markdown]
# ---
# ## Practice Challenges
#
# 1. Build a single list of all email addresses from both `customer` and `staff` tables, labelled by role
# 2. Use UNION ALL to show the 5 most expensive films and 5 cheapest films in one result set with a 'tier' label
# 3. Count the total number of rows across `rental` and `payment` tables using UNION ALL

# %%
# %%sql
# -- Q5: Build a single list of all email addresses from both the customer and staff tables — add a role column 'Customer' or 'Staff' — use UNION to deduplicate

# %%
# %%sql
# -- Q6: Use UNION ALL to show the 5 most expensive films by replacement_cost and the 5 cheapest — add a tier column 'Most Expensive' or 'Cheapest' — show title, replacement_cost, and tier

# %%
# %%sql
# -- Q7: Use UNION ALL to count the total combined row count across the rental and payment tables — show a single value labeled total_rows
